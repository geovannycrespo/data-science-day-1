# %% [markdown]
# # Exercises

# %% [markdown]
# ### #1 - Calculate the BMI (body mass index) on the two lists below using NDArrays...

# %%
import numpy as np
# formula = weight / (height**2) * 730
height = [69, 70, 71, 72, 73, 74, 75]
weight = [110, 120, 130, 140, 150, 160, 170]

bmi_height=np.array(height) 
bmi_weight=np.array(weight)
BMI=(bmi_weight / (bmi_height **2)) * 730 
print(BMI)
# Out:
# [16.86620458 17.87755102 18.82562984 19.71450617 20.54794521 21.32943755
#  22.06222222]

# %% [markdown]
# ### #2 - Create a function that will take in two parameters and will create a random matrix based off of those parameters. Extra: Have additional parameters taken in that allow the user to choose the shape and data type of the matrix.

# %%
def makeMatrix(low,high,shape,data_type = float):
    if data_type == int:
        return np.random.randit(low,high,shape)
    else:
        return np.random.uniform(low,high,shape)
makeMatrix(5,15,(3,3),data_type = float)
# Out:
# array([[ 6.3555733 , 12.42212747, 11.06638189],
#        [11.46982094,  6.36250126, 11.19559644],
#        [11.40928751,  9.97228844, 11.28116367]])

# %% [markdown]
# ### #3 - Extra: Open and load the data in the two text files that have the Boston Red Sox hitting data for the past seasons. Compare the difference in the two years by putting the data into an NDArray and running a differencial operation on it. The column to look for will be SLG.
#
# Your output should display which year (either 2017 or 2018) was a better year based on SLG

# %%
import csv
import numpy as np

#Test to make sure you have the correct data
def open_txt(filename, d=','):
    #Open CSV -- RedSox hitting.txt
    data = []
    
    with open(filename, encoding='utf-8') as mData:
        info = csv.reader(mData,delimiter=d)
        
        for row in info:
            data.append(row)
    return data

bs2017 = open_txt('files/redsox_2018_hitting.txt')
bs2017
# Out:
# [['Rk',
#   'Pos',
#   'Name',
#   'Age',
#   'G',
#   'PA',
#   'AB',
#   'R',
#   'H',
#   '2B',
#   '3B',
#   'HR',
#   'RBI',
#   'SB',
#   'CS',
#   'BB',
#   'SO',
#   'BA',
#   'OBP',
#   'SLG',
#   'OPS',
#   'OPS+',
#   'TB',
#   'GDP',
#   'HBP',
#   'SH',
#   'SF',
#   'IBB'],
#  ['1',
#   'C',
#   'Sandy Leon',
#   '29',
#   '89',
#   '288',
#   '265',
#   '30',
#   '47',
#   '12',
#   '0',
#   '5',
#   '22',
#   '1',
#   '0',
#   '15',
#   '75',
#   '.177',
#   '.232',
#   '.279',
#   '.511',
#   '37',
#   '74',
#   '6',
#   '4',
#   '3',
#   '1',
#   '0'],
#  ['2',
#   '1B',
#   'Mitch Moreland',
#   '32',
#   '124',
#   '459',
#   '404',
#   '57',
#   '99',
#   '23',
#   '4',
#   '15',
#   '68',
#   '2',
#   '0',
#   '50',
#   '102',
#   '.245',
#   '.325',
#   '.433',
#   '.758',
#   '102',
#   '175',
#   '12',
#   '0',
#   '0',
#   '5',
#   '2'],
#  ['3',
#   '2B',
#   'Eduardo Nunez',
#   '31',
#   '127',
#   '502',
#   '480',
#   '56',
#   '127',
#   '23',
#   '3',
#   '10',
#   '44',
#   '7',
#   '2',
#   '16',
#   '69',
#   '.265',
#   '.289',
#   '.388',
#   '.677',
#   '81',
#   '186',
#   '17',
#   '2',
#   '1',
#   '3',
#   '0'],
#  ['4',
#   'SS',
#   'Xander Bogaerts',
#   '25',
#   '136',
#   '580',
#   '513',
#   '72',
#   '148',
#   '45',
#   '3',
#   '23',
#   '103',
#   '8',
#   '2',
#   '55',
#   '102',
#   '.288',
#   '.360',
#   '.522',
#   '.883',
#   '135',
#   '268',
#   '14',
#   '6',
#   '0',
#   '6',
#   '4'],
#  ['5',
#   '3B',
#   'Rafael Devers',
#   '21',
#   '121',
#   '490',
#   '450',
#   '59',
#   '108',
#   '24',
#   '0',
#   '21',
#   '66',
#   '5',
#   '2',
#   '38',
#   '121',
#   '.240',
#   '.298',
#   '.433',
#   '.731',
#   '94',
#   '195',
#   '9',
#   '0',
#   '0',
#   '2',
#   '6'],
#  ['6',
#   'LF',
#   'Andrew Benintendi',
#   '23',
#   '148',
#   '661',
#   '579',
#   '103',
#   '168',
#   '41',
#   '6',
#   '16',
#   '87',
#   '21',
#   '3',
#   '71',
#   '106',
#   '.290',
#   '.366',
#   '.465',
#   '.830',
#   '123',
#   '269',
#   '9',
#   '2',
#   '2',
#   '7',
#   '1'],
#  ['7',
#   'CF',
#   'Jackie Bradley Jr.',
#   '28',
#   '144',
#   '535',
#   '474',
#   '76',
#   '111',
#   '33',
#   '4',
#   '13',
#   '59',
#   '17',
#   '1',
#   '46',
#   '137',
#   '.234',
#   '.314',
#   '.403',
#   '.717',
#   '92',
#   '191',
#   '6',
#   '11',
#   '0',
#   '4',
#   '3'],
#  ['8',
#   'RF',
#   'Mookie Betts',
#   '25',
#   '136',
#   '614',
#   '520',
#   '129',
#   '180',
#   '47',
#   '5',
#   '32',
#   '80',
#   '30',
#   '6',
#   '81',
#   '91',
#   '.346',
#   '.438',
#   '.640',
#   '1.078',
#   '186',
#   '333',
#   '5',
#   '8',
#   '0',
#   '5',
#   '8'],
#  ['9',
#   'DH',
#   'J.D. Martinez',
#   '30',
#   '150',
#   '649',
#   '569',
#   '111',
#   '188',
#   '37',
#   '2',
#   '43',
#   '130',
#   '6',
#   '1',
#   '69',
#   '146',
#   '.330',
#   '.402',
#   '.629',
#   '1.031',
#   '173',
#   '358',
#   '19',
#   '4',
#   '0',
#   '7',
#   '11'],
#  ['10',
#   'MI',
#   'Brock Holt',
#   '30',
#   '109',
#   '367',
#   '321',
#   '41',
#   '89',
#   '18',
#   '2',
#   '7',
#   '46',
#   '7',
#   '7',
#   '37',
#   '73',
#   '.277',
#   '.362',
#   '.411',
#   '.774',
#   '109',
#   '132',
#   '7',
#   '7',
#   '0',
#   '2',
#   '2'],
#  ['11',
#   'C',
#   'Christian Vazquez',
#   '27',
#   '80',
#   '269',
#   '251',
#   '24',
#   '52',
#   '10',
#   '0',
#   '3',
#   '16',
#   '4',
#   '1',
#   '13',
#   '41',
#   '.207',
#   '.257',
#   '.283',
#   '.540',
#   '46',
#   '71',
#   '5',
#   '4',
#   '1',
#   '0',
#   '1'],
#  ['12',
#   'UT',
#   'Blake Swihart',
#   '26',
#   '82',
#   '207',
#   '192',
#   '28',
#   '44',
#   '10',
#   '0',
#   '3',
#   '18',
#   '6',
#   '1',
#   '15',
#   '57',
#   '.229',
#   '.285',
#   '.328',
#   '.613',
#   '65',
#   '63',
#   '4',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['13',
#   'UT',
#   'Hanley Ramirez',
#   '34',
#   '44',
#   '195',
#   '177',
#   '25',
#   '45',
#   '7',
#   '0',
#   '6',
#   '29',
#   '4',
#   '1',
#   '14',
#   '35',
#   '.254',
#   '.313',
#   '.395',
#   '.708',
#   '90',
#   '70',
#   '9',
#   '2',
#   '0',
#   '2',
#   '0'],
#  ['14',
#   '1B',
#   'Steve Pearce',
#   '35',
#   '50',
#   '165',
#   '136',
#   '19',
#   '38',
#   '8',
#   '1',
#   '7',
#   '26',
#   '0',
#   '0',
#   '22',
#   '27',
#   '.279',
#   '.394',
#   '.507',
#   '.901',
#   '141',
#   '69',
#   '1',
#   '5',
#   '0',
#   '2',
#   '0'],
#  ['15',
#   '2B',
#   'Ian Kinsler',
#   '36',
#   '37',
#   '143',
#   '132',
#   '17',
#   '32',
#   '6',
#   '0',
#   '1',
#   '16',
#   '7',
#   '3',
#   '10',
#   '24',
#   '.242',
#   '.294',
#   '.311',
#   '.604',
#   '64',
#   '41',
#   '5',
#   '0',
#   '0',
#   '1',
#   '0'],
#  ['16',
#   'SS',
#   'Tzu-Wei Lin',
#   '24',
#   '37',
#   '73',
#   '65',
#   '15',
#   '16',
#   '6',
#   '1',
#   '1',
#   '6',
#   '0',
#   '1',
#   '8',
#   '17',
#   '.246',
#   '.329',
#   '.415',
#   '.744',
#   '100',
#   '27',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['17',
#   'UT',
#   'Sam Travis',
#   '24',
#   '19',
#   '38',
#   '36',
#   '5',
#   '8',
#   '3',
#   '0',
#   '1',
#   '7',
#   '0',
#   '0',
#   '2',
#   '10',
#   '.222',
#   '.263',
#   '.389',
#   '.652',
#   '73',
#   '14',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['18',
#   'UT',
#   'Brandon Phillips',
#   '37',
#   '9',
#   '27',
#   '23',
#   '4',
#   '3',
#   '0',
#   '0',
#   '1',
#   '2',
#   '0',
#   '0',
#   '4',
#   '7',
#   '.130',
#   '.259',
#   '.261',
#   '.520',
#   '42',
#   '6',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['19',
#   '2B',
#   'Dustin Pedroia',
#   '34',
#   '3',
#   '13',
#   '11',
#   '1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0',
#   '2',
#   '1',
#   '.091',
#   '.231',
#   '.091',
#   '.322',
#   '-7',
#   '1',
#   '0',
#   '0',
#   '0',
#   '0',
#   '0'],
#  ['20',
#   'C',
#   'Dan Butler',
#   '31',
#   '2',
#   '7',
#   '6',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0',
#   '2',
#   '.167',
#   '.143',
#   '.167',
#   '.310',
#   '-17',
#   '1',
#   '0',
#   '0',
#   '0',
#   '1',
#   '0']]

# %%
FIELDS = ['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 
          'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB']

DATATYPES = [('rk', 'i'), ('pos', '|S25'), ('name', '|S25'), ('age', 'i'), ('g', 'i'), ('pa', 'i'), ('ab', 'i'),
                ('r', 'i'), ('h', 'i'), ('2b', 'i'), ('3b', 'i'), ('hr', 'i'), ('rbi', 'i'), ('sb', 'i'), ('cs', 'i'),
                ('bb', 'i'), ('so', 'i'), ('ba', 'f'), ('obp', 'f'), ('slg', 'f'), ('ops', 'f'), ('opsp', 'i'),
                ('tb', 'i'), ('gdp', 'i'), ('hbp', 'i'), ('sh', 'i'), ('sf', 'i'), ('ibb', 'i')]

#Use this function to actually open the data inside of a NDArray

def load_data(filename, d=','):
    data = np.genfromtxt(filename,delimiter=d, skip_header = 1, usecols = np.arange(0,28), invalid_raise = False, names = FIELDS, dtype=DATATYPES)
#     Get data with a similar example to class lecture
    return data

bos_17 = load_data('files/redsox_2017_hitting.txt')
bos_18 = load_data('files/redsox_2018_hitting.txt')


def betterYear(cat):
    if sum(bos_17[cat] > sum(bos_18[cat])):
        print('boston 17 had more {} in 2017'.format(cat))
    else:
        print('Boston 18 had more {} in 2018'.format(cat))
        
betterYear('SLG')
# Out:
# Boston 18 had more SLG in 2018
